# %% [markdown]
# # Chapter 1: Basics of Python

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats.mstats import mquantiles
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %% [markdown]
# # Excercises

# %% [markdown]
# 1. Create a vector called x and place values 10 to 1000. Create a $y$ vector that takes the square root of the log of numbers in $x$. Plot $x$ and $y$

# %%
x = np.arange(10,1000)
y = np.sqrt(np.log(x))

# %%
plt.scatter(x,y,c='red',marker='x')

# %% [markdown]
# 2. In the R $\textbf{dataset}$ package there is a data set called $\textbf{airquality}$. In Python, load the $\textbf{airquality.csv}$ data file from the GitHub repository

# %%
airquality = pd.read_csv('../../data/airquality.csv')

# %%
airquality.head()
# Out:
#    Ozone  Solar.R  Wind  Temp  Month  Day
# 0   41.0    190.0   7.4    67      5    1
# 1   36.0    118.0   8.0    72      5    2
# 2   12.0    149.0  12.6    74      5    3
# 3   18.0    313.0  11.5    62      5    4
# 4    NaN      NaN  14.3    56      5    5

# %% [markdown]
# 1) Mean, median and 75th percentile values of $\textbf{Temp}$

# %%
temp = airquality['Temp']

# %%
print(np.mean(temp))
print(np.median(temp))
print(np.quantile(temp, .75))
# Out:
# 77.88235294117646
# 79.0
# 85.0

# %% [markdown]
# 2) Create a subset dataframe called $\textbf{s1}$ which has data for all days in June ### not explained in text

# %%
s1 = airquality[airquality['Month']==6]
s1.head()
# Out:
#     Ozone  Solar.R  Wind  Temp  Month  Day
# 31    NaN    286.0   8.6    78      6    1
# 32    NaN    287.0   9.7    74      6    2
# 33    NaN    242.0  16.1    67      6    3
# 34    NaN    186.0   9.2    84      6    4
# 35    NaN    220.0   8.6    85      6    5

# %% [markdown]
# 3) Draw a plot from $\textbf{s1}$ of $\textbf{Temp}$ and $\textbf{Solar.R}$

# %%
plot = s1.plot.scatter('Temp','Solar.R')

# %% [markdown]
# 4) What is the median value of $\textbf{Solar.R}$ in the $\textbf{s1}$ dataframe?

# %%
s1['Solar.R'].median()
# Out:
# 188.5

# %% [markdown]
# 3. In R, load the MASS package. There is a data set called Cars93. In Python, load the $\textbf{93cars.csv}$ data file

# %%
cars = pd.read_csv('../../data/93cars.csv')

# %%
cars.head(20)
# Out:
#    Manufacturer       Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura     Integra    Small       12.9   15.9       18.8        25
# 1         Acura      Legend  Midsize       29.2   33.9       38.7        18
# 2          Audi          90  Compact       25.9   29.1       32.3        20
# 3          Audi         100  Midsize       30.8   37.7       44.6        19
# 4           BMW        535i  Midsize       23.7   30.0       36.2        22
# 5         Buick     Century  Midsize       14.2   15.7       17.3        22
# 6         Buick     LeSabre    Large       19.9   20.8       21.7        19
# 7         Buick  Roadmaster    Large       22.6   23.7       24.9        16
# 8         Buick     Riviera  Midsize       26.3   26.3       26.3        19
# 9      Cadillac     DeVille    Large       33.0   34.7       36.3        16
# 10     Cadillac     Seville  Midsize       37.5   40.1       42.7        16
# ...

# %% [markdown]
# 1) Mean, median, and 25th percentile values of $\textbf{MPG}$ on high way

# %%
print(cars['MPG.highway'].mean())
print(cars['MPG.highway'].median())
print(mquantiles(cars['MPG.highway'], 0.25))
# Out:
# 29.086021505376344
# 28.0
# [26.]

# %% [markdown]
# 2) Create a subset dataframe called $\textbf{p1}$ which has data for all Non-4WD cars that weigh over 3500

# %%
# no Non-4WD information

# %% [markdown]
# 3) Draw a plot from $\textbf{p1}$ of price and horsepower

# %% [markdown]
# 4) What is the median luggage room in the $\textbf{p1}$ dataframe?

# %% [markdown]
# 4. In R, install the package $\textbf{plm}$, load the library and load the data using the command $\textbf{data(Males)}$. In Python, load $\textbf{Males.csv}$ from the repository.

# %%
males = pd.read_csv('../../data/Males.csv')

# %%
males.head()
# Out:
#    nr  year  school  exper union   ethn married health      wage  \
# 0  13  1980      14      1    no  other      no     no  1.197540
# 1  13  1981      14      2   yes  other      no     no  1.853060
# 2  13  1982      14      3    no  other      no     no  1.344462
# 3  13  1983      14      4    no  other      no     no  1.433213
# 4  13  1984      14      5    no  other      no     no  1.568125
#
#                       industry                      occupation   residence
# 0  Business_and_Repair_Service                 Service_Workers  north_east
# 1             Personal_Service                 Service_Workers  north_east
# 2  Business_and_Repair_Service                 Service_Workers  north_east
# 3  Business_and_Repair_Service                 Service_Workers  north_east
# 4             Personal_Service  Craftsmen, Foremen_and_kindred  north_east

# %% [markdown]
# 1) Create a frequency table between industry and residence. ### not explained in text Where do people in manufacturing mostly live and by what proportion? What proportion of people in the south are in Transportation? What is the most popular industry for people living in rural_area?

# %%
males.groupby(['industry'])['residence'].value_counts()
# Out:
# industry                          residence
# Agricultural                      south               48
#                                   nothern_central     19
#                                   rural_area          18
#                                   north_east           9
# Business_and_Repair_Service       south               97
#                                   north_east          84
#                                   nothern_central     51
#                                   rural_area           5
# Construction                      south              108
#                                   nothern_central     42
#                                   north_east          37
#                                   rural_area           5
# Entertainment                     nothern_central     26
#                                   north_east          10
#                                   south               10
#                                   rural_area           2
# ...
